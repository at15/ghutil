# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# lg = pd.read_csv('awesome_go_logging.csv')
# TODO: should have a function for that ....
lg = pd.read_csv('awesome_go_web.txt.csv')
lg.head()
# Out:
#             created_at  forks  issues               name            pushed_at  \
# 0  2016-07-20 12:09:48      6       0          sheng/air  2018-05-16 03:23:09
# 1  2017-12-09 13:35:31      1       1    nsheremet/banjo  2018-01-31 16:42:14
# 2  2012-02-29 02:32:08   3329     494      astaxie/beego  2018-05-09 02:54:10
# 3  2015-03-01 17:43:01    906     116      labstack/echo  2018-05-09 21:05:11
# 4  2016-07-20 05:04:54      2       0  zpatrick/fireball  2018-04-26 19:47:42
#
#    stars           updated_at                                   url  watchers
# 0     66  2018-05-16 03:23:10          https://github.com/sheng/air        66
# 1      1  2018-01-04 08:17:56    https://github.com/nsheremet/banjo         1
# 2  15289  2018-05-16 01:48:29      https://github.com/astaxie/beego     15289
# 3  10347  2018-05-16 04:22:52      https://github.com/labstack/echo     10347
# 4     34  2018-05-01 00:51:28  https://github.com/zpatrick/fireball        34

# %%
lg_by_star = lg.sort_values(by=['stars'], ascending=False)
lg_by_star.head(20)
# Out:
#              created_at  forks  issues                    name  \
# 7   2014-06-16 23:57:25   2033     209           gin-gonic/gin
# 2   2012-02-29 02:32:08   3329     494           astaxie/beego
# 3   2015-03-01 17:43:01    906     116           labstack/echo
# 20  2011-12-09 04:10:26   1242      66             revel/revel
# 8   2013-02-19 03:15:45    332      42    ant0ine/go-json-rest
# 11  2014-12-05 07:17:53    277      31           goadesign/goa
# 15  2014-07-10 03:13:30    220      12      go-macaron/macaron
# 26  2015-09-16 07:55:54    135       6           gernest/utron
# 24  2013-02-09 21:16:13     76      28  rcrowley/go-tigertonic
# 23  2014-12-17 03:07:09    105       9             lunny/tango
# 25  2013-08-09 15:39:44     26       0            pilu/traffic
# 14  2016-06-22 11:52:42     13       5    mustafaakin/gongular
# 18  2015-02-04 19:16:06     36       6             ivpusic/neo
# 16  2011-05-25 07:26:46     36       9       paulbellamy/mango
# ...
